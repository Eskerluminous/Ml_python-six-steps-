# %% [markdown]
# <a href="https://colab.research.google.com/github/Eskerluminous/Ml_python-six-steps-/blob/main/Basic_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
list=['Berlin','Brazil','Dhaka']
list
# Out:
# ['Berlin', 'Brazil', 'Dhaka']

# %%
df=pd.DataFrame(list)
df
# Out:
#         0
# 0  Berlin
# 1  Brazil
# 2   Dhaka

# %%
row,col=df.shape

# %%
row
col
# Out:
# 1

# %%
df=pd.DataFrame(list,columns=['City in Euroupe'])
df
# Out:
#   City in Euroupe
# 0          Berlin
# 1          Brazil
# 2           Dhaka

# %%
df=pd.DataFrame(list,columns=['City_in_Euroupe'],index=['c1','c2','c3'])
df
# Out:
#    City_in_Euroupe
# c1          Berlin
# c2          Brazil
# c3           Dhaka

# %%
list2=['kendua','pabna','Bogura']
df2=pd.DataFrame(zip(list,list2),columns=['city1','city2'],index=['c1','c2','c3'])
df2
# Out:
#      city1   city2
# c1  Berlin  kendua
# c2  Brazil   pabna
# c3   Dhaka  Bogura

# %%
df2.shape
# Out:
# (3, 2)

# %%
dict2={
    'list':list,
    'list2':list2
}

# %%
dict2
# Out:
# {'list': ['Berlin', 'Brazil', 'Dhaka'], 'list2': ['kendua', 'pabna', 'Bogura']}

# %%
df5=pd.DataFrame(dict2)
df5
# Out:
#      list   list2
# 0  Berlin  kendua
# 1  Brazil   pabna
# 2   Dhaka  Bogura

# %%
type(dict2)
# Out:
# dict

# %%
df6=pd.read_csv('/content/Screentime - App Details.csv')
df6
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 1   08/27/2022     39             43            48  Instagram
# 2   08/28/2022     64            231            55  Instagram
# 3   08/29/2022     14             35            23  Instagram
# 4   08/30/2022      3             19             5  Instagram
# 5   08/31/2022     19             25            20  Instagram
# 6   09/01/2022     44             23            57  Instagram
# 7   09/02/2022     16             28            22  Instagram
# 8   09/03/2022     27             15            25  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 10  09/05/2022     42             24            51  Instagram
# 11  09/06/2022     19             34            25  Instagram
# 12  09/07/2022     38             23            19  Instagram
# 13  09/08/2022     71             48            43  Instagram
# ...

# %%
type(df6)  #type check
# Out:
# pandas.core.frame.DataFrame

# %%
df6.head() #first 5 rows shows here
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram

# %%
df6.tail()  #last 5 rows shows here
# Out:
#           Date  Usage  Notifications  Times opened       App
# 49  09/17/2022    212            212           120  Whatsapp
# 50  09/18/2022    244            303           132  Whatsapp
# 51  09/19/2022     77            169           105  Whatsapp
# 52  09/20/2022     58            190            78  Whatsapp
# 53  09/21/2022     89            262            68  Whatsapp

# %%
df6.head(10)
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram
# 5  08/31/2022     19             25            20  Instagram
# 6  09/01/2022     44             23            57  Instagram
# 7  09/02/2022     16             28            22  Instagram
# 8  09/03/2022     27             15            25  Instagram
# 9  09/04/2022     72             29            30  Instagram

# %%
df6.values
# Out:
# array([['08/26/2022', 38, 70, 49, 'Instagram'],
#        ['08/27/2022', 39, 43, 48, 'Instagram'],
#        ['08/28/2022', 64, 231, 55, 'Instagram'],
#        ['08/29/2022', 14, 35, 23, 'Instagram'],
#        ['08/30/2022', 3, 19, 5, 'Instagram'],
#        ['08/31/2022', 19, 25, 20, 'Instagram'],
#        ['09/01/2022', 44, 23, 57, 'Instagram'],
#        ['09/02/2022', 16, 28, 22, 'Instagram'],
#        ['09/03/2022', 27, 15, 25, 'Instagram'],
#        ['09/04/2022', 72, 29, 30, 'Instagram'],
#        ['09/05/2022', 42, 24, 51, 'Instagram'],
#        ['09/06/2022', 19, 34, 25, 'Instagram'],
#        ['09/07/2022', 38, 23, 19, 'Instagram'],
#        ['09/08/2022', 71, 48, 43, 'Instagram'],
#        ['09/09/2022', 43, 68, 70, 'Instagram'],
#        ['09/10/2022', 45, 71, 70, 'Instagram'],
#        ['09/11/2022', 94, 180, 95, 'Instagram'],
#        ['09/12/2022', 114, 99, 102, 'Instagram'],
#        ['09/13/2022', 17, 45, 39, 'Instagram'],
#        ['09/14/2022', 1, 10, 2, 'Instagram'],
# ...

# %%
df6.columns
# Out:
# Index(['Date', 'Usage', 'Notifications', 'Times opened', 'App'], dtype='object')

# %%
df6.shape
# Out:
# (54, 5)

# %%
df6.index
# Out:
# RangeIndex(start=0, stop=54, step=1)

# %%
df6['Usage'].sort_values()
# Out:
# 35      1
# 19      1
# 26      2
# 20      2
# 22      2
# 4       3
# 21      3
# 23      3
# 24      4
# 25      5
# 36      6
# 3      14
# 7      16
# 18     17
# 5      19
# 11     19
# 33     23
# 8      27
# 0      38
# 12     38
# 1      39
# 10     42
# 14     43
# 6      44
# 15     45
# 47     50
# 52     58
# 30     59
# 46     64
# 2      64
# 28     69
# 40     69
# 48     71
# 45     71
# 13     71
# 9      72
# 34     76
# 51     77
# 27     82
# 53     89
# 38     91
# 16     94
# 42    103
# 32    108
# 17    114
# 41    119
# 37    126
# 31    128
# 29    130
# 39    160
# 44    182
# 43    203
# 49    212
# 50    244
# Name: Usage, dtype: int64

# %%
df6.describe()
# Out:
#             Usage  Notifications  Times opened
# count   54.000000      54.000000     54.000000
# mean    65.037037     117.703704     61.481481
# std     58.317272      97.017530     43.836635
# min      1.000000       8.000000      2.000000
# 25%     17.500000      25.750000     23.500000
# 50%     58.500000      99.000000     62.500000
# 75%     90.500000     188.250000     90.000000
# max    244.000000     405.000000    192.000000

# %%
df6.corr()
# Out:
#                   Usage  Notifications  Times opened
# Usage          1.000000       0.774452      0.816409
# Notifications  0.774452       1.000000      0.882983
# Times opened   0.816409       0.882983      1.000000

# %%
import seaborn as sns
sns.heatmap(df6.corr(),annot=True)

# %%
df6[df6['Usage']>50]
# Out:
#           Date  Usage  Notifications  Times opened        App
# 2   08/28/2022     64            231            55  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 13  09/08/2022     71             48            43  Instagram
# 16  09/11/2022     94            180            95  Instagram
# 17  09/12/2022    114             99           102  Instagram
# 27  08/26/2022     82            209           105   Whatsapp
# 28  08/27/2022     69            111            68   Whatsapp
# 29  08/28/2022    130            183            86   Whatsapp
# 30  08/29/2022     59            157            74   Whatsapp
# 31  08/30/2022    128            246            87   Whatsapp
# 32  08/31/2022    108            169            77   Whatsapp
# 34  09/02/2022     76            144           103   Whatsapp
# 37  09/05/2022    126            218           121   Whatsapp
# 38  09/06/2022     91            205           110   Whatsapp
# ...

# %%
#subset rows
df6[(df6['Usage']<50) & (df6['App'] == 'Whatsapp')]
# Out:
#           Date  Usage  Notifications  Times opened       App
# 33  09/01/2022     23             99            47  Whatsapp
# 35  09/03/2022      1             80            16  Whatsapp
# 36  09/04/2022      6             38            33  Whatsapp

# %%
df6[df6['App'].isin (['Whatsapp','Instagram'])]
# Out:
#           Date  Usage  Notifications  Times opened        App
# 0   08/26/2022     38             70            49  Instagram
# 1   08/27/2022     39             43            48  Instagram
# 2   08/28/2022     64            231            55  Instagram
# 3   08/29/2022     14             35            23  Instagram
# 4   08/30/2022      3             19             5  Instagram
# 5   08/31/2022     19             25            20  Instagram
# 6   09/01/2022     44             23            57  Instagram
# 7   09/02/2022     16             28            22  Instagram
# 8   09/03/2022     27             15            25  Instagram
# 9   09/04/2022     72             29            30  Instagram
# 10  09/05/2022     42             24            51  Instagram
# 11  09/06/2022     19             34            25  Instagram
# 12  09/07/2022     38             23            19  Instagram
# 13  09/08/2022     71             48            43  Instagram
# ...
